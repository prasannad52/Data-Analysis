# %% [markdown]
# ## univariate analysis non graphical

# %%
import pandas as pd
filepath = 'C:\\Users\\Prasanna dindi\\python\\prasanna.csv'
df = pd.read_csv(filepath,encoding='ISO-8859-1')

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace = True)

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df['id'] = df['id'].astype(str)
df['host_id'] = df['host_id'].astype(str)
df['latitude'] = df['latitude'].astype(str)
df['longitude'] = df['longitude'].astype(str)

# %%
df.describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  38821.000000    38821.000000       38821.000000       38821.000000
# mean     142.332526        5.869220          29.290255           1.373229
# std      196.994756       17.389026          48.182900           1.680328
# min        0.000000        1.000000           1.000000           0.010000
# 25%       69.000000        1.000000           3.000000           0.190000
# 50%      101.000000        2.000000           9.000000           0.720000
# 75%      170.000000        4.000000          33.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    38821.000000      38821.000000
# mean                         5.166611        114.886299
# std                         26.302954        129.529950
# min                          1.000000          0.000000
# ...

# %%
df.nunique()
# Out:
# id                                38821
# name                              38240
# host_id                           30232
# host_name                          9880
# neighbourhood_group                   5
# neighbourhood                       218
# latitude                          17436
# longitude                         13639
# room_type                             3
# price                               581
# minimum_nights                       89
# number_of_reviews                   393
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        16621
# Brooklyn         16439
# Queens            4572
# Bronx              875
# Staten Island      314
# Name: neighbourhood_group, dtype: int64

# %%
df['neighbourhood_group'].value_counts(normalize=True)
# Out:
# Manhattan        0.428145
# Brooklyn         0.423456
# Queens           0.117771
# Bronx            0.022539
# Staten Island    0.008088
# Name: neighbourhood_group, dtype: float64

# %%
df_n = df['neighbourhood'].value_counts().reset_index().rename(columns={'index': 'neighbourhood','neighbourhood':"no_of_hotels"})

# %%
df_n
# Out:
#           neighbourhood  no_of_hotels
# 0          Williamsburg          3163
# 1    Bedford-Stuyvesant          3141
# 2                Harlem          2204
# 3              Bushwick          1942
# 4        Hell's Kitchen          1528
# ..                  ...           ...
# 213          Holliswood             2
# 214      New Dorp Beach             2
# 215        Richmondtown             1
# 216           Rossville             1
# 217         Willowbrook             1
#
# [218 rows x 2 columns]

# %%
df_n[df_n['no_of_hotels']>500]
# Out:
#          neighbourhood  no_of_hotels
# 0         Williamsburg          3163
# 1   Bedford-Stuyvesant          3141
# 2               Harlem          2204
# 3             Bushwick          1942
# 4       Hell's Kitchen          1528
# 5         East Village          1489
# 6      Upper West Side          1482
# 7      Upper East Side          1405
# 8        Crown Heights          1265
# 9              Midtown           986
# 10         East Harlem           943
# 11          Greenpoint           866
# 12             Chelsea           827
# 13     Lower East Side           738
# 14  Washington Heights           721
# 15             Astoria           709
# 16        West Village           610
# 17  Financial District           509

# %%
df['price'].value_counts(bins= bins)
# Out:
# (100.0, 500.0]       18811
# (50.0, 100.0]        14212
# (-0.001, 50.0]        5176
# (500.0, 1000.0]        515
# (1000.0, 5000.0]        98
# (5000.0, 10000.0]        9
# Name: price, dtype: int64

# %%
bins = (0,50,100,500,1000,5000,10000)

# %%
df['price'].mean()
# Out:
# 142.33252621004095

# %%
df['price'].std()
# Out:
# 196.99475591833985

# %%
df['price'].kurt()
# Out:
# 953.4807356344944

# %%
df['price'].skew()
# Out:
# 23.673594295123014

# %%
df.corr()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000        0.025501          -0.035924
# minimum_nights                  0.025501        1.000000          -0.069366
# number_of_reviews              -0.035924       -0.069366           1.000000
# reviews_per_month              -0.030623       -0.121712           0.549699
# calculated_host_listings_count  0.052895        0.073474          -0.059796
# availability_365                0.078276        0.101658           0.193409
#
#                                 reviews_per_month  \
# price                                   -0.030623
# minimum_nights                          -0.121712
# number_of_reviews                        0.549699
# reviews_per_month                        1.000000
# calculated_host_listings_count          -0.009442
# availability_365                         0.185896
#
#                                 calculated_host_listings_count  \
# ...

# %% [markdown]
# # univariate analysis graphical

# %%
import seaborn as sns
sns.countplot(data = df,x = 'neighbourhood_group')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.countplot(data = df,x = 'neighbourhood_group',hue = 'room_type')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %%
df['room_type'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='room_type'>

# %%
df['neighbourhood_group'].value_counts().plot(kind = 'pie',autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='neighbourhood_group'>

# %%
dfd = sns.load_dataset('titanic')

# %%
dfd
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## histogram

# %%
import seaborn as sns
sns.histplot(data = df,x = 'price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df[df['price']<500],x = 'price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\Prasanna dindi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['availability_365'])
# Out:
# C:\Users\Prasanna dindi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='availability_365', ylabel='Density'>

# %%
sns.boxplot(df['availability_365'])
# Out:
# C:\Users\Prasanna dindi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='availability_365'>

# %%
sns.boxplot(df['price'])
# Out:
# C:\Users\Prasanna dindi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
sns.boxplot(dfd['age'])
# Out:
# C:\Users\Prasanna dindi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
sns.violinplot(df['price'])
# Out:
# C:\Users\Prasanna dindi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
sns.violinplot(dfd['age'])
# Out:
# C:\Users\Prasanna dindi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
sns.barplot(x = 'class' ,y = 'age',data = dfd,hue='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.barplot(x = 'class' ,y = 'age',data = dfd,hue='sex',estimator = sum)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.barplot(x = 'class' ,y = 'fare',data = dfd ,estimator = sum)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sns.boxplot(data = dfd, x = 'class',y = 'age',hue = 'survived')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.countplot(x = 'survived',data = dfd)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
import pandas as pd
x = pd.crosstab(dfd['survived'],dfd['class'])

# %%
x
# Out:
# class     First  Second  Third
# survived
# 0            80      97    372
# 1           136      87    119

# %%
sns.heatmap(x,annot = True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.scatterplot(data = df, x = 'age', y = 'fare', hue = 'survived')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
df2 = sns.load_dataset('tips')

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = df2,hue = 'size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = 'total_bill', y = 'tip' ,hue = 'sex', data = df2)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
fig = sns.scatterplot(x = 'total_bill', y = 'tip', data = df2,hue = 'size', style = 'smoker')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df2)

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df3 = sns.load_dataset('flights')

# %%
df3
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.scatterplot(x = 'year', y = 'passengers',data = df3 )
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
df4=df3['year'].value_counts()

# %%
df4.reset_index()
# Out:
#     index  year
# 0    1949    12
# 1    1950    12
# 2    1951    12
# 3    1952    12
# 4    1953    12
# 5    1954    12
# 6    1955    12
# 7    1956    12
# 8    1957    12
# 9    1958    12
# 10   1959    12
# 11   1960    12

# %%
sns.scatterplot(x = 'index', y = 'year', data = df4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22092\99050292.py in <module>
# ----> 1 sns.scatterplot(x = 'index', y = 'year', data = df4)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
#     809         data=data, variables=variables,
# ...

# %%
sns.lineplot(x = 'year', y = 'passengers',data = df3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('List of Countries by Sugarcane Production.csv')
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %%
df.shape
# Out:
# (103, 7)

# %%
df.describe()
# Out:
#        Unnamed: 0
# count  103.000000
# mean    51.000000
# std     29.877528
# min      0.000000
# 25%     25.500000
# 50%     51.000000
# 75%     76.500000
# max    102.000000

# %%
df.isnull().count()
# Out:
# Unnamed: 0                    103
# Country                       103
# Continent                     103
# Production (Tons)             103
# Production per Person (Kg)    103
# Acreage (Hectare)             103
# Yield (Kg / Hectare)          103
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.isnull()
# Out:
#      Unnamed: 0  Country  Continent  Production (Tons)  \
# 0         False    False      False              False
# 1         False    False      False              False
# 2         False    False      False              False
# 3         False    False      False              False
# 4         False    False      False              False
# ..          ...      ...        ...                ...
# 98        False    False      False              False
# 99        False    False      False              False
# 100       False    False      False              False
# 101       False    False      False              False
# 102       False    False      False              False
#
#      Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                         False              False                 False
# 1                         False              False                 False
# 2                         False              False                 False
# ...

# %%
df['Production (Tons)'] = df['Production (Tons)'].str.replace('.','')
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace('.','').str.replace(',','.')
df['Acreage (Hectare)'] = df['Acreage (Hectare)'].str.replace('.','')
df["Yield (Kg / Hectare)"] = df["Yield (Kg / Hectare)"].str.replace('.','').str.replace(',','.')
# Out:
# C:\Users\Prasanna dindi\AppData\Local\Temp\ipykernel_22092\3126883907.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Production (Tons)'] = df['Production (Tons)'].str.replace('.','')
# C:\Users\Prasanna dindi\AppData\Local\Temp\ipykernel_22092\3126883907.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace('.','').str.replace(',','.')
# ...

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America         768678382
# 1             1      India           Asia         348448000
# 2             2      China           Asia         123059739
# 3             3   Thailand           Asia          87468496
# 4             4   Pakistan           Asia          65450704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                     3668.531          10226205              75167.5
# 1                       260721           4950000              70393.5
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df[df['Acreage (Hectare)'].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %%
df = df.dropna().reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production (Tons)  \
# 0      0           0    Brazil  South America         768678382
# 1      1           1     India           Asia         348448000
# 2      2           2     China           Asia         123059739
# 3      3           3  Thailand           Asia          87468496
# 4      4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.isnull().sum()
# Out:
# index                         0
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             0
# Yield (Kg / Hectare)          0
# dtype: int64

# %%
df.drop(['index','Unnamed: 0'],axis = 1, inplace = True)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df.rename(columns = {'Production (Tons)':'Production(Tons)','Production per Person (Kg)': 'Production_per_Person(Kg)','Acreage (Hectare)':'Acreage(Hectare)',"Yield (Kg / Hectare":"Yield(Kg / Hectare"},inplace = True )

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield (Kg / Hectare)
# 0         10226205              75167.5
# 1          4950000              70393.5
# 2          1675215              73459.1
# 3          1336575              65442.2
# 4          1130820                57879

# %%
df['Production(Tons)'] = df['Production(Tons)'].astype(float)
df['Production_per_Person(Kg)'] = df['Production_per_Person(Kg)'].astype(float)
df['Acreage(Hectare)'] = df['Acreage(Hectare)'].astype(float)
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].astype(float)

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield (Kg / Hectare)
# 0        10226205.0               75167.5
# 1         4950000.0               70393.5
# 2         1675215.0               73459.1
# 3         1336575.0               65442.2
# 4         1130820.0               57879.0

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield (Kg / Hectare)
# count            102.000000
# mean           52628.078431
# std            30504.676683
# min               10.000000
# 25%            29072.025000
# 50%            54108.950000
# 75%            73282.700000
# max           129049.300000

# %%
df['Production(Tons)'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield (Kg / Hectare)         float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield (Kg / Hectare)         102
# dtype: int64

# %%
df['Continent'].value_counts()
# Out:
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64

# %%
df['Continent'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,1,1)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,1,1)
# Out:
# <AxesSubplot:>

# %%
df_new = df[['Country','Production(Tons)']].set_index('Country')

# %%
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new['Production(Tons)_percent'] =  df_new['Production(Tons)']*100/df_new['Production(Tons)'].sum()

# %%
df_new
# Out:
#            Production(Tons)  Production(Tons)_percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new['Production(Tons)_percent'].plot(kind = 'pie', autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='Production(Tons)_percent'>

# %%
df_new['Production(Tons)'].head(10).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
ax = sns.barplot(data = df.head(10),x = 'Country',y = 'Production(Tons)')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %%
df_acr = df.sort_values('Acreage(Hectare)',ascending = False)

# %%
ax = sns.barplot(data = df_acr.head(10),x = 'Country',y = 'Acreage(Hectare)')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %%
df.corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_Person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield (Kg / Hectare)               0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield (Kg / Hectare)
# Production(Tons)                   0.997550              0.132812
# Production_per_Person(Kg)          0.012557              0.017999
# Acreage(Hectare)                   1.000000              0.113433
# Yield (Kg / Hectare)               0.113433              1.000000

# %%
sns.heatmap(df.corr(),annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
df_continent = df.groupby('Continent').sum()

# %%
df_continent
# Out:
#                Unnamed: 0
# Continent
# Africa               2160
# Asia                 1253
# Europe                189
# North America        1101
# Oceania               227
# South America         323

# %%
df_continent.sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22092\4169013404.py in <module>
# ----> 1 df_continent.sort_values(ascending = False)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
